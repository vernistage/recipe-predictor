# %%
import pandas as pd
import gensim

# %%
ls
# Out:
# epi_r.csv
# epicurious-recipes-with-rating-and-nutrition.zip
# full_format_recipes.json
# recipe.py
# recipeWizard.ipynb
# utils.py

# %%
df = pd.read_json("full_format_recipes.json")

# %%
df.head()
# Out:
#    calories                                         categories  \
# 0     426.0  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1     403.0  [Food Processor, Onion, Pork, Bake, Bastille D...
# 2     165.0  [Soup/Stew, Dairy, Potato, Vegetable, Fennel, ...
# 3       NaN  [Fish, Olive, Tomato, Sauté, Low Fat, Low Cal,...
# 4     547.0  [Cheese, Dairy, Pasta, Vegetable, Side, Bake, ...
#
#                  date                                               desc  \
# 0 2006-09-01 04:00:00                                               None
# 1 2004-08-20 04:00:00  This uses the same ingredients found in boudin...
# 2 2004-08-20 04:00:00                                               None
# 3 2009-03-27 04:00:00  The Sicilian-style tomato sauce has tons of Me...
# 4 2004-08-20 04:00:00                                               None
#
#                                           directions   fat  \
# 0  [1. Place the stock, lentils, celery, carrot, ...   7.0
# 1  [Combine first 9 ingredients in heavy medium s...  23.0
# 2  [In a large heavy saucepan cook diced fennel a...   7.0
# 3  [Heat oil in heavy large skillet over medium-h...   NaN
# 4  [Preheat oven to 350°F. Lightly grease 8x8x2-i...  32.0
#
#                                          ingredients  protein  rating  sodium  \
# 0  [4 cups low-sodium vegetable or chicken stock,...     30.0   2.500   559.0
# 1  [1 1/2 cups whipping cream, 2 medium onions, c...     18.0   4.375  1439.0
# 2  [1 fennel bulb (sometimes called anise), stalk...      6.0   3.750   165.0
# 3  [2 tablespoons extra-virgin olive oil, 1 cup c...      NaN   5.000     NaN
# 4  [1 12-ounce package frozen spinach soufflé, th...     20.0   3.125   452.0
#
#                                          title
# 0              Lentil, Apple, and Turkey Wrap
# 1  Boudin Blanc Terrine with Red Onion Confit
# 2                Potato and Fennel Soup Hodge
# 3             Mahi-Mahi in Tomato Olive Sauce
# 4                    Spinach Noodle Casserole

# %%
line = df.iloc[0]["directions"]
# df.at[0,"directions"]
# df.get_value(0,"directions")

# %%
type(line)
# Out:
# list

# %%
line
# Out:
# ['1. Place the stock, lentils, celery, carrot, thyme, and salt in a medium saucepan and bring to a boil. Reduce heat to low and simmer until the lentils are tender, about 30 minutes, depending on the lentils. (If they begin to dry out, add water as needed.) Remove and discard the thyme. Drain and transfer the mixture to a bowl; let cool.',
#  '2. Fold in the tomato, apple, lemon juice, and olive oil. Season with the pepper.',
#  '3. To assemble a wrap, place 1 lavash sheet on a clean work surface. Spread some of the lentil mixture on the end nearest you, leaving a 1-inch border. Top with several slices of turkey, then some of the lettuce. Roll up the lavash, slice crosswise, and serve. If using tortillas, spread the lentils in the center, top with the turkey and lettuce, and fold up the bottom, left side, and right side before rolling away from you.']

# %%
directions1 = ",".join(line)

# %%
gensim.utils.simple_preprocess(directions1)
# Out:
# ['place',
#  'the',
#  'stock',
#  'lentils',
#  'celery',
#  'carrot',
#  'thyme',
#  'and',
#  'salt',
#  'in',
#  'medium',
#  'saucepan',
#  'and',
#  'bring',
#  'to',
#  'boil',
#  'reduce',
#  'heat',
#  'to',
#  'low',
#  'and',
#  'simmer',
#  'until',
#  'the',
#  'lentils',
#  'are',
#  'tender',
#  'about',
#  'minutes',
#  'depending',
#  'on',
#  'the',
#  'lentils',
#  'if',
#  'they',
#  'begin',
#  'to',
#  'dry',
#  'out',
#  'add',
#  'water',
#  'as',
#  'needed',
#  'remove',
#  'and',
#  'discard',
#  'the',
#  'thyme',
#  'drain',
#  'and',
#  'transfer',
#  'the',
#  'mixture',
#  'to',
#  'bowl',
#  'let',
#  'cool',
#  'fold',
#  'in',
#  'the',
#  'tomato',
#  'apple',
#  'lemon',
#  'juice',
#  'and',
#  'olive',
#  'oil',
#  'season',
#  'with',
#  'the',
#  'pepper',
#  'to',
#  'assemble',
#  'wrap',
#  'place',
#  'lavash',
#  'sheet',
#  'on',
#  'clean',
#  'work',
#  'surface',
#  'spread',
#  'some',
#  'of',
#  'the',
#  'lentil',
#  'mixture',
#  'on',
#  'the',
#  'end',
#  'nearest',
#  'you',
#  'leaving',
#  'inch',
#  'border',
#  'top',
#  'with',
#  'several',
#  'slices',
#  'of',
#  'turkey',
#  'then',
#  'some',
#  'of',
#  'the',
#  'lettuce',
#  'roll',
#  'up',
#  'the',
#  'lavash',
#  'slice',
#  'crosswise',
#  'and',
#  'serve',
#  'if',
#  'using',
#  'tortillas',
#  'spread',
#  'the',
#  'lentils',
#  'in',
#  'the',
#  'center',
#  'top',
#  'with',
#  'the',
#  'turkey',
#  'and',
#  'lettuce',
#  'and',
#  'fold',
#  'up',
#  'the',
#  'bottom',
#  'left',
#  'side',
#  'and',
#  'right',
#  'side',
#  'before',
#  'rolling',
#  'away',
#  'from',
#  'you']

# %%
def process_line_item(dir_list):
    try:
        directions = ",".join(dir_list)
        gensim_dir = gensim.utils.simple_preprocess(directions)
        return gensim_dir
    except:
        return ''

# %%
df["gensim_directions"] = df["directions"].map(process_line_item)

# %%
df.head()
# Out:
#    calories                                         categories  \
# 0     426.0  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1     403.0  [Food Processor, Onion, Pork, Bake, Bastille D...
# 2     165.0  [Soup/Stew, Dairy, Potato, Vegetable, Fennel, ...
# 3       NaN  [Fish, Olive, Tomato, Sauté, Low Fat, Low Cal,...
# 4     547.0  [Cheese, Dairy, Pasta, Vegetable, Side, Bake, ...
#
#                  date                                               desc  \
# 0 2006-09-01 04:00:00                                               None
# 1 2004-08-20 04:00:00  This uses the same ingredients found in boudin...
# 2 2004-08-20 04:00:00                                               None
# 3 2009-03-27 04:00:00  The Sicilian-style tomato sauce has tons of Me...
# 4 2004-08-20 04:00:00                                               None
#
#                                           directions   fat  \
# 0  [1. Place the stock, lentils, celery, carrot, ...   7.0
# 1  [Combine first 9 ingredients in heavy medium s...  23.0
# 2  [In a large heavy saucepan cook diced fennel a...   7.0
# 3  [Heat oil in heavy large skillet over medium-h...   NaN
# 4  [Preheat oven to 350°F. Lightly grease 8x8x2-i...  32.0
#
#                                          ingredients  protein  rating  sodium  \
# 0  [4 cups low-sodium vegetable or chicken stock,...     30.0   2.500   559.0
# 1  [1 1/2 cups whipping cream, 2 medium onions, c...     18.0   4.375  1439.0
# 2  [1 fennel bulb (sometimes called anise), stalk...      6.0   3.750   165.0
# 3  [2 tablespoons extra-virgin olive oil, 1 cup c...      NaN   5.000     NaN
# 4  [1 12-ounce package frozen spinach soufflé, th...     20.0   3.125   452.0
#
#                                          title  \
# 0              Lentil, Apple, and Turkey Wrap
# 1  Boudin Blanc Terrine with Red Onion Confit
# 2                Potato and Fennel Soup Hodge
# 3             Mahi-Mahi in Tomato Olive Sauce
# 4                    Spinach Noodle Casserole
#
#                                    gensim_directions
# 0  [place, the, stock, lentils, celery, carrot, t...
# 1  [combine, first, ingredients, in, heavy, mediu...
# 2  [in, large, heavy, saucepan, cook, diced, fenn...
# 3  [heat, oil, in, heavy, large, skillet, over, m...
# 4  [preheat, oven, to, lightly, grease, inch, gla...

# %%
# build vocabulary and train model
model = gensim.models.Word2Vec(
    df["gensim_directions"],
    size=150,
    window=10,
    min_count=2,
    workers=10)
model.train(df["gensim_directions"], total_examples=len(df["gensim_directions"]), epochs=10)
# Out:
# (20340244, 27698530)

# %%
w1 = 'beans'
model.wv.most_similar(positive=w1)
# Out:
# /Users/anna/anaconda3/envs/pytorch/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('chickpeas', 0.6085021495819092),
#  ('peas', 0.550258994102478),
#  ('tomatoes', 0.47675663232803345),
#  ('onions', 0.4735875725746155),
#  ('potatoes', 0.4611278176307678),
#  ('lentils', 0.46014919877052307),
#  ('eyed', 0.45917707681655884),
#  ('bright', 0.45618748664855957),
#  ('cannellini', 0.45147764682769775),
#  ('farro', 0.4476720690727234)]
